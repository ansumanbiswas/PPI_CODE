# %%
import pandas as pd
 

feature_train = pd.read_csv("feature_train.csv")

# %%
feature_test = pd.read_csv("feature_test.csv")

# %%
feature_train
# Out:
#          Unnamed: 0    Index        K0        Ht        Hp         P  \
# 0                 0      199  0.590000  0.255556  0.311111  0.120000
# 1                 1      200  0.337778  0.196667  0.381111  0.241111
# 2                 2      201  0.325556  0.196667  0.393333  0.241111
# 3                 3      202  0.328889  0.201111  0.308889  0.343333
# 4                 4      203  0.281111  0.165556  0.223333  0.450000
# ...             ...      ...       ...       ...       ...       ...
# 1660116     1660116  2073358  0.334444  0.352222  0.505556  0.024444
# 1660117     1660117  2073359  0.292222  0.370000  0.486667  0.127778
# 1660118     1660118  2073360  0.283333  0.370000  0.487778  0.132222
# 1660119     1660119  2073361  0.255556  0.355556  0.442222  0.135556
# 1660120     1660120  2073362  0.255556  0.355556  0.442222  0.135556
#
#               pHi        pK        Mw        Bl  ...  FASG760101  FASG760102  \
# ...

# %%
uid = []
for i in feature_train['id'] :
#    print(i.split('_')[0])
    uid.append(i.split('_')[0])

# %%
len(uid)
# Out:
# 1660121

# %%
import numpy as np
len(np.unique(uid))
# Out:
# 3668

# %%
import numpy as np
x = np.array(uid)
print(np.unique(x))
# Out:
# ['19HC' '1A92' '1AUO' ... '6g3w' '6g4q' '6ins']

# %%
z = pd.DataFrame(np.unique(x))
np.random.seed(25)
train, train_sample = np.split(z.sample(frac=1), [int(0.8*len(z))])
print(train)
print(train_sample)
# Out:
#          0
# 975   1yra
# 906   1xg2
# 1679   3C2
# 2360  3w8i
# 1184  2dqr
# ...    ...
# 662   1rxq
# 3090   5EC
# 3136  5bxv
# 96    1ayo
# 571   1p5t
#
# [2934 rows x 1 columns]
#          0
# 2485  4c57
# 1955  3hoc
# 2626  4hd0
# 3035  4yek
# 3362  5ky7
# ...    ...
# 3389  5lrx
# 2191  3pzd
# 2522  4dbq
# 318   1h9h
# 1156  2cmy
#
# [734 rows x 1 columns]

# %%
##not needed
feature_train['uid'] = uid

# %%
feature_train
# Out:
#          Unnamed: 0    Index        K0        Ht        Hp         P  \
# 0                 0      199  0.590000  0.255556  0.311111  0.120000
# 1                 1      200  0.337778  0.196667  0.381111  0.241111
# 2                 2      201  0.325556  0.196667  0.393333  0.241111
# 3                 3      202  0.328889  0.201111  0.308889  0.343333
# 4                 4      203  0.281111  0.165556  0.223333  0.450000
# ...             ...      ...       ...       ...       ...       ...
# 1660116     1660116  2073358  0.334444  0.352222  0.505556  0.024444
# 1660117     1660117  2073359  0.292222  0.370000  0.486667  0.127778
# 1660118     1660118  2073360  0.283333  0.370000  0.487778  0.132222
# 1660119     1660119  2073361  0.255556  0.355556  0.442222  0.135556
# 1660120     1660120  2073362  0.255556  0.355556  0.442222  0.135556
#
#               pHi        pK        Mw        Bl  ...  FASG760101  FASG760102  \
# ...

# %%
train_sample.rename(columns = {0:'uid'}, inplace = True)

# %%
feature_train_sample = pd.merge(feature_train, train_sample, on='uid', how='inner')

# %%
feature_train_sample
# Out:
#         Unnamed: 0    Index        K0        Ht        Hp         P       pHi  \
# 0             2840     4175  0.403333  0.280000  0.288889  0.130000  0.328889
# 1             2841     4176  0.457778  0.168889  0.388889  0.016667  0.377778
# 2             2842     4177  0.526667  0.247778  0.361111  0.016667  0.386667
# 3             2843     4178  0.447778  0.264444  0.341111  0.123333  0.376667
# 4             2844     4179  0.447778  0.264444  0.341111  0.123333  0.376667
# ...            ...      ...       ...       ...       ...       ...       ...
# 318352     1660025  2072885  0.408889  0.443333  0.438889  0.323333  0.376667
# 318353     1660026  2072886  0.456667  0.478889  0.524444  0.216667  0.386667
# 318354     1660027  2072887  0.412222  0.508889  0.567778  0.216667  0.386667
# 318355     1660028  2072888  0.403333  0.460000  0.541111  0.220000  0.373333
# 318356     1660029  2072889  0.441111  0.533333  0.642222  0.113333  0.384444
#
# ...

# %%
import matplotlib.pyplot as plt
from collections import Counter
class_freq = Counter(feature_train_sample['class'])
print(class_freq)
plt.bar(class_freq.keys(), class_freq.values())
# Out:
# Counter({0: 260435, 1: 57922})
# <BarContainer object of 2 artists>

# %%
a = feature_train_sample.drop(['Unnamed: 0', 'Index', 'id', 'fragment', 'class', 'uid'], 1)

# %%
a
# Out:
#               K0        Ht        Hp         P       pHi        pK        Mw  \
# 0       0.403333  0.280000  0.288889  0.130000  0.328889  0.693333  0.414444
# 1       0.457778  0.168889  0.388889  0.016667  0.377778  0.836667  0.296667
# 2       0.526667  0.247778  0.361111  0.016667  0.386667  0.824444  0.293333
# 3       0.447778  0.264444  0.341111  0.123333  0.376667  0.807778  0.355556
# 4       0.447778  0.264444  0.341111  0.123333  0.376667  0.807778  0.355556
# ...          ...       ...       ...       ...       ...       ...       ...
# 318352  0.408889  0.443333  0.438889  0.323333  0.376667  0.661111  0.388889
# 318353  0.456667  0.478889  0.524444  0.216667  0.386667  0.675556  0.363333
# 318354  0.412222  0.508889  0.567778  0.216667  0.386667  0.673333  0.387778
# 318355  0.403333  0.460000  0.541111  0.220000  0.373333  0.704444  0.380000
# 318356  0.441111  0.533333  0.642222  0.113333  0.384444  0.614444  0.365556
#
# ...

# %%
list(a.columns)
# Out:
# ['K0',
#  'Ht',
#  'Hp',
#  'P',
#  'pHi',
#  'pK',
#  'Mw',
#  'Bl',
#  'Rf',
#  'Mu',
#  'Hnc',
#  'Esm',
#  'El',
#  'Et',
#  'Pa',
#  'Pb',
#  'Pt',
#  'Pc',
#  'Ca',
#  'F',
#  'Br',
#  'Ra',
#  'Ns',
#  'aN',
#  'aC',
#  'aM',
#  'V0',
#  'Nm',
#  'Nl',
#  'Hgm',
#  'ASAD',
#  'ASAN',
#  'dASA',
#  'dGh',
#  'GhD',
#  'GhN',
#  'dHh',
#  '-TdSh',
#  'dCph',
#  'dGc',
#  'dHc',
#  '-TdSc',
#  'dG',
#  'dH',
#  '-TdS',
#  'v',
#  's',
#  'f',
#  'Pf-s',
#  'GEIM800105',
#  'GEIM800108',
#  'BIOV880102',
#  'GRAR740102',
#  'GRAR740103',
#  'HOPA770101',
#  'ISOY800102',
#  'ISOY800103',
#  'ISOY800104',
#  'JOND750101',
#  'JUKT750101',
#  'KANM800102',
#  'KANM800103',
#  'KARP850101',
#  'KRIW710101',
#  'KRIW790101',
#  'LAWE840101',
#  'LEVM760101',
#  'LIFS790101',
#  'LIFS790103',
#  'MANP780101',
#  'MAXF760102',
#  'MAXF760106',
#  'MIYS850101',
#  'NAGK730102',
#  'NAGK730103',
#  'BURA740102',
#  'ARGP820101',
#  'NISK860101',
#  'OOBM770103',
#  'OOBM850103',
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
feature_train_sample_scale = scaler.fit_transform(a)

# %%
feature_train_sample_scale
# Out:
# array([[-0.20190728, -0.75637207, -1.12221252, ...,  0.42381571,
#         -0.1425149 , -0.53519725],
#        [ 0.41675988, -2.02780577, -0.0308612 , ...,  0.64492924,
#         -1.49990091, -1.38499916],
#        [ 1.19956323, -1.12508784, -0.33401434, ...,  0.52055288,
#         -1.24242669, -1.3512322 ],
#        ...,
#        [-0.1009004 ,  1.86278133,  1.92144506, ...,  1.94742609,
#         -0.8336299 ,  0.34415075],
#        [-0.20190728,  1.30335051,  1.63041804, ...,  1.05260729,
#         -0.76813208, -0.12858674],
#        [ 0.22737197,  2.14249675,  2.73389549, ...,  1.96124568,
#         -0.72747825,  0.11481679]])

# %%
type(feature_train_sample_scale)
# Out:
# numpy.ndarray

# %%
feature_train_sample_scale1 = pd.DataFrame(feature_train_sample_scale, columns =list(a.columns))

# %%
feature_train_sample_scale1
# Out:
#               K0        Ht        Hp         P       pHi        pK        Mw  \
# 0      -0.201907 -0.756372 -1.122213 -0.980965 -1.344232 -0.511182 -0.141880
# 1       0.416760 -2.027806 -0.030861 -1.784144 -0.623889  1.154392 -1.679782
# 2       1.199563 -1.125088 -0.334014 -1.784144 -0.492918  1.012366 -1.723308
# 3       0.303127 -0.934373 -0.552285 -1.028211 -0.640261  0.818695 -0.910831
# 4       0.303127 -0.934373 -0.552285 -1.028211 -0.640261  0.818695 -0.910831
# ...          ...       ...       ...       ...       ...       ...       ...
# 318352 -0.138778  1.112635  0.514814  0.389164 -0.640261 -0.885613 -0.475576
# 318353  0.404134  1.519494  1.448526 -0.366769 -0.492918 -0.717765 -0.809272
# 318354 -0.100900  1.862781  1.921445 -0.366769 -0.492918 -0.743588 -0.490085
# 318355 -0.201907  1.303351  1.630418 -0.343146 -0.689375 -0.382068 -0.591644
# 318356  0.227372  2.142497  2.733895 -1.099080 -0.525661 -1.427893 -0.780255
#
# ...

# %%
feature_train_sample_scale2 = pd.DataFrame(feature_train_sample_scale)

# %%
feature_train_sample_scale2
# Out:
#              0         1         2         3         4         5         6    \
# 0      -0.201907 -0.756372 -1.122213 -0.980965 -1.344232 -0.511182 -0.141880
# 1       0.416760 -2.027806 -0.030861 -1.784144 -0.623889  1.154392 -1.679782
# 2       1.199563 -1.125088 -0.334014 -1.784144 -0.492918  1.012366 -1.723308
# 3       0.303127 -0.934373 -0.552285 -1.028211 -0.640261  0.818695 -0.910831
# 4       0.303127 -0.934373 -0.552285 -1.028211 -0.640261  0.818695 -0.910831
# ...          ...       ...       ...       ...       ...       ...       ...
# 318352 -0.138778  1.112635  0.514814  0.389164 -0.640261 -0.885613 -0.475576
# 318353  0.404134  1.519494  1.448526 -0.366769 -0.492918 -0.717765 -0.809272
# 318354 -0.100900  1.862781  1.921445 -0.366769 -0.492918 -0.743588 -0.490085
# 318355 -0.201907  1.303351  1.630418 -0.343146 -0.689375 -0.382068 -0.591644
# 318356  0.227372  2.142497  2.733895 -1.099080 -0.525661 -1.427893 -0.780255
#
# ...

# %%
cor2 = feature_train_sample_scale2.corr()

# %%
cor = feature_train_sample_scale1.corr()

# %%
cor
# Out:
#                   K0        Ht        Hp         P       pHi        pK  \
# K0          1.000000 -0.111841 -0.010428 -0.393822  0.221826  0.140829
# Ht         -0.111841  1.000000  0.501501 -0.057910  0.126316 -0.320169
# Hp         -0.010428  0.501501  1.000000 -0.464678 -0.042482 -0.151706
# P          -0.393822 -0.057910 -0.464678  1.000000  0.354450 -0.208187
# pHi         0.221826  0.126316 -0.042482  0.354450  1.000000 -0.121056
# ...              ...       ...       ...       ...       ...       ...
# FASG760102  0.083696  0.326272  0.699851 -0.432572  0.049741  0.302852
# FAUJ830101 -0.051560  0.566511  0.563307 -0.386157 -0.526726 -0.043874
# FAUJ880101 -0.246721  0.665188  0.518144 -0.010511  0.091411 -0.475795
# FAUJ880106 -0.376726  0.519105  0.036234  0.371634  0.390789 -0.331068
# BIGC670101 -0.534562  0.636924  0.235124  0.375417  0.394951 -0.309853
#
#                   Mw        Bl        Rf        Mu  ...  MIYS990101  \
# ...

# %%
pos_corr = pd.DataFrame()
for column in cor2:

    cor_target = abs(cor2[column])

    relevant_features = cor_target[cor_target>0.7]
    print('Column Name : ', column)

    pos_corr = relevant_features.to_frame()
    print(pos_corr)
# Out:
# Column Name :  0
#      0
# 0  1.0
# Column Name :  1
#             1
# 1    1.000000
# 7    0.737477
# 32   0.735407
# 38   0.846635
# 58   0.973376
# 65   0.749817
# 76   0.973270
# 92   0.969451
# 96   0.872982
# 97   0.733443
# 109  0.727872
# 110  0.747268
# Column Name :  2
#             2
# 2    1.000000
# 12   0.906853
# 13   0.745506
# 15   0.844005
# 19   0.849093
# 20   0.860643
# 21   0.872089
# 22   0.933749
# 28   0.875754
# 29   0.874356
# 38   0.737999
# 67   0.747997
# 69   0.710805
# 72   0.714977
# 84   0.853657
# 86   0.778953
# 87   0.729054
# 118  0.710771
# 119  0.702314
# 120  0.724870
# Column Name :  3
#            3
# 3   1.000000
# 13  0.746284
# 31  0.796819
# 47  0.726344
# Column Name :  4
#      4
# 4  1.0
# Column Name :  5
#      5
# 5  1.0
# Column Name :  6
#             6
# 6    1.000000
# 9    0.848483
# 11   0.869670
# 18   0.919130
# 26   0.904593
# 30   0.933375
# 32   0.715265
# 36   0.827656
# 37   0.757331
# 40   0.724233
# 45   0.990441
# ...

# %%
feature_train_sample_scale2
# Out:
#              0         1         2         3         4         5         6    \
# 0      -0.201907 -0.756372 -1.122213 -0.980965 -1.344232 -0.511182 -0.141880
# 1       0.416760 -2.027806 -0.030861 -1.784144 -0.623889  1.154392 -1.679782
# 2       1.199563 -1.125088 -0.334014 -1.784144 -0.492918  1.012366 -1.723308
# 3       0.303127 -0.934373 -0.552285 -1.028211 -0.640261  0.818695 -0.910831
# 4       0.303127 -0.934373 -0.552285 -1.028211 -0.640261  0.818695 -0.910831
# ...          ...       ...       ...       ...       ...       ...       ...
# 318352 -0.138778  1.112635  0.514814  0.389164 -0.640261 -0.885613 -0.475576
# 318353  0.404134  1.519494  1.448526 -0.366769 -0.492918 -0.717765 -0.809272
# 318354 -0.100900  1.862781  1.921445 -0.366769 -0.492918 -0.743588 -0.490085
# 318355 -0.201907  1.303351  1.630418 -0.343146 -0.689375 -0.382068 -0.591644
# 318356  0.227372  2.142497  2.733895 -1.099080 -0.525661 -1.427893 -0.780255
#
# ...

# %%
feature_train_sample_scale2_mod = feature_train_sample_scale2[[0,1,2,3,4,5,6,8,10,14,24,25,33,41,54,55,57,62,71,73,79,81,88,95,122,125]]

# %%
feature_train_sample_scale2_mod['class'] = feature_train_sample['class']
# Out:
# <ipython-input-38-6af9216538e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_train_sample_scale2_mod['class'] = feature_train_sample['class']

# %%
feature_train_sample_scale2_mod
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.201907 -0.756372 -1.122213 -0.980965 -1.344232 -0.511182 -0.141880
# 1       0.416760 -2.027806 -0.030861 -1.784144 -0.623889  1.154392 -1.679782
# 2       1.199563 -1.125088 -0.334014 -1.784144 -0.492918  1.012366 -1.723308
# 3       0.303127 -0.934373 -0.552285 -1.028211 -0.640261  0.818695 -0.910831
# 4       0.303127 -0.934373 -0.552285 -1.028211 -0.640261  0.818695 -0.910831
# ...          ...       ...       ...       ...       ...       ...       ...
# 318352 -0.138778  1.112635  0.514814  0.389164 -0.640261 -0.885613 -0.475576
# 318353  0.404134  1.519494  1.448526 -0.366769 -0.492918 -0.717765 -0.809272
# 318354 -0.100900  1.862781  1.921445 -0.366769 -0.492918 -0.743588 -0.490085
# 318355 -0.201907  1.303351  1.630418 -0.343146 -0.689375 -0.382068 -0.591644
# 318356  0.227372  2.142497  2.733895 -1.099080 -0.525661 -1.427893 -0.780255
#
# ...

# %%
feature_train_sample
# Out:
#         Unnamed: 0    Index        K0        Ht        Hp         P       pHi  \
# 0             2840     4175  0.403333  0.280000  0.288889  0.130000  0.328889
# 1             2841     4176  0.457778  0.168889  0.388889  0.016667  0.377778
# 2             2842     4177  0.526667  0.247778  0.361111  0.016667  0.386667
# 3             2843     4178  0.447778  0.264444  0.341111  0.123333  0.376667
# 4             2844     4179  0.447778  0.264444  0.341111  0.123333  0.376667
# ...            ...      ...       ...       ...       ...       ...       ...
# 318352     1660025  2072885  0.408889  0.443333  0.438889  0.323333  0.376667
# 318353     1660026  2072886  0.456667  0.478889  0.524444  0.216667  0.386667
# 318354     1660027  2072887  0.412222  0.508889  0.567778  0.216667  0.386667
# 318355     1660028  2072888  0.403333  0.460000  0.541111  0.220000  0.373333
# 318356     1660029  2072889  0.441111  0.533333  0.642222  0.113333  0.384444
#
# ...

# %%
feature_train_sample_scale2_mod['uid'] = feature_train_sample['uid']
# Out:
# <ipython-input-43-2291145cc4e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_train_sample_scale2_mod['uid'] = feature_train_sample['uid']

# %%
#feature_train_sample_scale2_mod['class'] = feature_train_sample['class']

# %%
feature_train_sample_scale2_mod.to_csv('feature_train_sample_scale2_mod.csv')

# %%
class_freq2 = Counter(feature_train_sample_scale2_mod['class'])
print(class_freq2)
plt.bar(class_freq2.keys(), class_freq2.values())
# Out:
# Counter({0: 260435, 1: 57922})
# <BarContainer object of 2 artists>

# %%
import seaborn as sns

sns.violinplot(x='class', y= 1, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 2, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 3, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
0,1,2,3,4,5,6,8,10,14,24,25,33,41,54,55,57,62,71,73,79,81,88,95,122,125]]

# %%
sns.violinplot(x='class', y= 0, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 4, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 5, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 6, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 8, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 10, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 14, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 24, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y=25, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 33, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 41, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 54, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 55, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 57, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 62, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 71, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 73, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 79, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 81, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 88, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 95, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 122, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
sns.violinplot(x='class', y= 125, data=feature_train_sample_scale2_mod,
               inner="quart", linewidth=1)

# %%
###balance data##
from sklearn.model_selection import train_test_split
from sklearn.ensemble._forest import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_recall_fscore_support
Rf = RandomForestClassifier()
X = feature_train_sample_scale2_mod.drop('class', axis =1)
y = feature_train_sample_scale2_mod['class']
X_train_bal, X_test_bal, y_train_bal, y_test_bal = train_test_split(X, y, test_size = 0.2, random_state = 101)

# %%
#'''
# https://towardsdatascience.com/fine-tuning-a-classifier-in-scikit-learn-66e048c21e65
# c=10,g=0.1 ; c=0.1,g=1 ; c=1,g=0.01 ; c=10,g=0.01  -> from older runs

from sklearn.metrics import make_scorer,recall_score,accuracy_score,precision_score   #roc_curve, precision_recall_curve, auc, confusion_matrix
from sklearn.model_selection import GridSearchCV, StratifiedKFold   # train_test_split,

#clf = SVC(class_weight='balanced') #n_jobs=-1)  # this runs the computation in parallel

#param_grid = [
  #{'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#  {'C': [0.01, 0.1, 1, 10], 'gamma': [0.01, 0.1], 'kernel': ['rbf']},
# ]

'''
{'bootstrap': True,
 'ccp_alpha': 0.0,
 'class_weight': None,
 'criterion': 'gini',
 'max_depth': None,
 'max_features': 'auto',
 'max_leaf_nodes': None,
 'max_samples': None,
 'min_impurity_decrease': 0.0,
 'min_samples_leaf': 1,
 'min_samples_split': 2,
 'min_weight_fraction_leaf': 0.0,
 'n_estimators': 100,
 'n_jobs': None,
 'oob_score': False,
 'random_state': None,
 'verbose': 0,
 'warm_start': False}
'''


# Number of trees in random forest
n_estimators = [200] #[int(x) for x in np.linspace(start = 200, stop = 1000, num = 200)]
# Number of features to consider at every split
#max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [40]
# Minimum number of samples required to split a node
#min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
#min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True] #, False]
class_weight = ["balanced"]

# Create the param grid
param_grid = {'n_estimators': n_estimators,
               #'max_features': max_features,
               'max_depth': max_depth,
               #'min_samples_split': min_samples_split,
               #'min_samples_leaf': min_samples_leaf,
              'class_weight' : class_weight,
               'bootstrap': bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [200], 'max_depth': [40], 'class_weight': ['balanced'], 'bootstrap': [True]}

# %%
clf = RandomForestClassifier()


scorers = {
    'precision_score': make_scorer(precision_score),
    'recall_score': make_scorer(recall_score),
    'accuracy_score': make_scorer(accuracy_score)
}



def grid_search_wrapper(X_train_scaled, y_train, X_test_scaled, y_test,refit_score='recall_score',):
    """
    fits a GridSearchCV classifier using refit_score for optimization
    prints classifier performance metrics
    """
    skf = StratifiedKFold(n_splits = 4)
    grid_search_clf = GridSearchCV(clf, param_grid, scoring=scorers, refit=refit_score,
                           cv=skf, return_train_score=True, n_jobs=-1)
    grid_search_clf.fit(X_train_scaled, y_train.values)  # X_train.values
    print('grid done!')

    print('Best params for {}'.format(refit_score))
    print(grid_search_clf.best_params_)
    
    results = pd.DataFrame(grid_search_clf.cv_results_)
    #results = results[['n_estimators','max_depth','mean_train_recall_score','mean_test_recall_score','mean_train_accuracy_score','mean_test_accuracy_score','mean_train_precision_score','mean_test_precision_score']] 
   
    
    # make the predictions
    y_pred = grid_search_clf.predict(X_test_scaled.values)

    # confusion matrix on the test data.
    print('\nConfusion matrix of SVM optimized for {} on the test data:'.format(refit_score))
    print(pd.DataFrame(confusion_matrix(y_test, y_pred),
                 columns=['pred_neg', 'pred_pos'], index=['neg', 'pos']))
    return grid_search_clf, results
#'''

# %%
from datetime import datetime
print(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
print('')

### run grid search ###
grid_search_clf, results = grid_search_wrapper(X_train_bal,y_train_bal,X_test_bal,y_test_bal,refit_score='recall_score',)

print('')
print(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2022-03-07 13:14:46
#
# grid done!
# Best params for recall_score
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 40, 'n_estimators': 200}
#
# Confusion matrix of SVM optimized for recall_score on the test data:
#      pred_neg  pred_pos
# neg     49359      2570
# pos      6712      5031
#
# 2022-03-07 13:23:46

# %%
y_pred_bal = grid_search_clf.predict(X_test_bal.values)
print(classification_report(y_test_bal, y_pred_bal))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91     51929
#            1       0.66      0.43      0.52     11743
#
#     accuracy                           0.85     63672
#    macro avg       0.77      0.69      0.72     63672
# weighted avg       0.84      0.85      0.84     63672

# %%
y_pred_bal_1 = grid_search_clf.predict_proba(X_test_bal)[:,[1]]

# %%
# vary threshold & get metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_recall_fscore_support 
cut_off=np.arange(0,1,.05)

metric = []
#sensitivity=[]
#specificity=[]
for m in cut_off:
    array=np.zeros(len(y_pred_bal_1))
    array_ind=[i for i in range(len(y_pred_bal_1)) if y_pred_bal_1[i]>=m]
    array[array_ind]=1
    p=precision_recall_fscore_support(y_test_bal,array) 
    sensitivity = p[1][1]  # sensitivity.append(p[1][1])
    specificity = p[1][0]  # specificity.append(p[1][0])
    metric.append([m,sensitivity, specificity])
#sensitivity=pd.DataFrame(np.array(sensitivity))
#specificity=pd.DataFrame(np.array(specificity))
metric = pd.DataFrame(metric,columns=['thres', 'sensitivity', 'specificity'])
# Out:
# /home/csrd003/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
metric
# Out:
#     thres  sensitivity  specificity
# 0    0.00     1.000000     0.000000
# 1    0.05     0.954271     0.198714
# 2    0.10     0.890488     0.463325
# 3    0.15     0.818956     0.607734
# 4    0.20     0.690028     0.760365
# 5    0.25     0.558546     0.876851
# 6    0.30     0.487865     0.923030
# 7    0.35     0.460189     0.937203
# 8    0.40     0.449204     0.942441
# 9    0.45     0.441540     0.945984
# 10   0.50     0.428425     0.950509
# 11   0.55     0.412501     0.955516
# 12   0.60     0.392489     0.962295
# 13   0.65     0.361918     0.967398
# 14   0.70     0.246956     0.976718
# 15   0.75     0.119901     0.986751
# 16   0.80     0.079622     0.992393
# 17   0.85     0.065486     0.994319
# 18   0.90     0.043090     0.997574
# 19   0.95     0.020863     0.999210

# %%
from sklearn import metrics
plt.figure(figsize=(8,6))
plt.scatter(x=1-pd.np.array(metric.iloc[:,[2]]),y=pd.np.array(metric.iloc[:,[1]]))

# %%
results = pd.DataFrame(grid_search_clf.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     294.420094      5.709894         4.561196        0.030399
#
#   param_bootstrap param_class_weight param_max_depth param_n_estimators  \
# 0            True           balanced              40                200
#
#                                               params  \
# 0  {'bootstrap': True, 'class_weight': 'balanced'...
#
#    split0_test_precision_score  ...  split3_test_accuracy_score  \
# 0                     0.635026  ...                    0.846822
#
#    mean_test_accuracy_score  std_test_accuracy_score  \
# 0                  0.846304                 0.000807
#
#    rank_test_accuracy_score  split0_train_accuracy_score  \
# 0                         1                     0.966657
#
#    split1_train_accuracy_score  split2_train_accuracy_score  \
# 0                     0.966636                     0.966447
#
#    split3_train_accuracy_score  mean_train_accuracy_score  \
# ...

# %%
m = 0.45
array=np.zeros(len(y_pred_bal_1))
array_ind=[i for i in range(len(y_pred_bal_1)) if y_pred_bal_1[i]>=m]
array[array_ind]=1
print(classification_report(y_test_bal, array))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91     51929
#            1       0.65      0.44      0.53     11743
#
#     accuracy                           0.85     63672
#    macro avg       0.77      0.69      0.72     63672
# weighted avg       0.84      0.85      0.84     63672

# %%
clf2 = RandomForestClassifier(n_estimators=200,
    criterion='gini',
    max_depth=40,
    bootstrap=True,
    random_state=0,
    verbose=0,
    class_weight={0:1, 1:5})


scorers = {
    'precision_score': make_scorer(precision_score),
    'recall_score': make_scorer(recall_score),
    'accuracy_score': make_scorer(accuracy_score)
}



def grid_search_wrapper(X_train_scaled, y_train, X_test_scaled, y_test,refit_score='recall_score',):
    """
    fits a GridSearchCV classifier using refit_score for optimization
    prints classifier performance metrics
    """
    skf = StratifiedKFold(n_splits = 4)
    grid_search_clf = GridSearchCV(clf2, param_grid, scoring=scorers, refit=refit_score,
                           cv=skf, return_train_score=True, n_jobs=-1)
    grid_search_clf.fit(X_train_scaled, y_train.values)  # X_train.values
    print('grid done!')

    print('Best params for {}'.format(refit_score))
    print(grid_search_clf.best_params_)
    
    results = pd.DataFrame(grid_search_clf.cv_results_)
    #results = results[['n_estimators','max_depth','mean_train_recall_score','mean_test_recall_score','mean_train_accuracy_score','mean_test_accuracy_score','mean_train_precision_score','mean_test_precision_score']] 
   
    
    # make the predictions
    y_pred = grid_search_clf.predict(X_test_scaled.values)

    # confusion matrix on the test data.
    print('\nConfusion matrix of SVM optimized for {} on the test data:'.format(refit_score))
    print(pd.DataFrame(confusion_matrix(y_test, y_pred),
                 columns=['pred_neg', 'pred_pos'], index=['neg', 'pos']))
    return grid_search_clf, results
#'''

# %%
from datetime import datetime
print(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
print('')

### run grid search ###
grid_search_clf, results = grid_search_wrapper(X_train_bal,y_train_bal,X_test_bal,y_test_bal,refit_score='recall_score',)

print('')
print(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2022-03-07 15:45:24
#
# grid done!
# Best params for recall_score
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 40, 'n_estimators': 200}
#
# Confusion matrix of SVM optimized for recall_score on the test data:
#      pred_neg  pred_pos
# neg     49351      2578
# pos      6700      5043
#
# 2022-03-07 15:55:38

# %%
y_pred_bal = grid_search_clf.predict(X_test_bal.values)
print(classification_report(y_test_bal, y_pred_bal))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91     51929
#            1       0.66      0.43      0.52     11743
#
#     accuracy                           0.85     63672
#    macro avg       0.77      0.69      0.72     63672
# weighted avg       0.84      0.85      0.84     63672
